# %%
import numpy as np
import pandas as pd
import spacy
import nltk 
import requests
import json
import googletrans
import random

from random import randint
from nltk.stem import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
from spacy.lang.en import English
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from nltk.corpus import wordnet 
from googletrans import Translator

spacy.load('en_core_web_sm')
nltk.download('stopwords')
en_stop = set(nltk.corpus.stopwords.words('english'))

analyser = SentimentIntensityAnalyzer()
parser = English()
porter = PorterStemmer()
translator = Translator()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/ninagroot/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
file = 'edit-db_model2.xlsx'
df_gratitude = pd.read_excel(file, 'gratitude')
#df_exercises = pd.read_excel('exercises_model2.xlsx')
df_journal = pd.read_excel(file, 'sc_journal')

topics = {
    'social media': ['social', 'media', 'network', 'twitter', 'facebook', 'instagram', 'web', 'linkedin', 'google', 'viral', 'google+', 'event', 'website', 'reach', 'telegraph', 'telephone', 'blog', 'internet', 'social', 'sociality', 'technoself', 'intranet', 'cyber', 'business', 'sociable', 'activist', 'microblogging', 'socially', 'cybernetic', 'pinterest', 'youtube', 'tumblr', 'cyberspace', 'extranet', 'telnet', 'cybernetics', 'modem', 'communication', 'informatics', 'virtual', 'party', 'picture'],
    'body insecurity': ['body insecurity', 'body', 'insecure', 'belly', 'skin', 'waist', 'hair', 'eyes', 'lips', 'ears', 'forehead', 'eyebrow', 'chin', 'scar', 'nose', 'look', 'eat', 'ate', 'boldness', 'beard', 'smile', 'teeth', 'stomach', 'back', 'ass', 'butt', 'frame', 'feature', 'physique', 'bod', 'bodies', 'torso', 'arm', 'head', 'corpse', 'chest', 'shape', 'shoulder', 'form', 'neck', 'structure', 'leg', 'mass', 'weight', 'shaky', 'unattractive', 'unsure', 'anxious', 'jealous', 'unconfident', 'distrustful', 'uncomfortable', 'unsecured', 'neurotic', 'hopeless', 'depressed', 'introverted', 'helpless', 'fragile', 'danger', 'anxiety', 'mistrust', 'instability', 'unrest', 'hardship', 'vulnerability', 'lawlessness', 'uncertainty', 'turmoil', 'strife', 'fragility', 'hopelessness', 'malnutrition', 'alienation', 'violence', 'poverty', 'tension', 'shortages', 'despair', 'chaos', 'distrust', 'resentment', 'underdevelopment', 'anarchy', 'paranoia', 'cynicism', 'fear', 'scared', 'insecure', 'fearful'],
    'social anxiety': ['social anxiety', 'shyness', 'blushing', 'fear', 'worry', 'stress', 'nervousness', 'attention', 'shame', 'panic', 'social', 'attack', 'own', 'activities', 'lonely', 'alone', 'rejection', 'public', 'speaking', 'nausea', 'stutter', 'acting', 'performance', 'stage', 'fright', 'fear', 'public', 'shyness', 'blushing', 'anxiety', 'self-consciousness', 'panic', 'illness', 'mood disorder', 'timidness', 'social functioning', 'parties', 'outgoing', 'illness', 'peer rejection', 'stutter', 'stage fright', 'guilt', 'panic attack'],
    'relationships' : ['friendship', 'best', 'friend', 'classmate', 'schoolmate', 'roomie', 'boyfriend', 'sister', 'amigo', 'acquanitance', 'brother', 'comerade', 'girlfriend', 'person', 'pal', 'schoolfriend', 'mate', 'colleague', 'roommate', 'love', 'pal', 'buddy', 'talk', 'soulmate', 'fight', 'trust', 'understanding', 'happiness', 'relations', 'empathy', 'company', 'feelings', 'unity', 'friendship', 'friend', 'companionship', 'relationship', 'relation', 'friendship', 'affinity', 'kinship', 'affiliation', 'association', 'partnership', 'acquaintance', 'state', 'consanguinity', 'sisterhood', 'brotherhood', 'membership', 'human relationship', 'family relationship', 'relate', 'relational', 'interrelation', 'family', 'partner', 'relatedness', 'relatedness', 'correlate', 'parentage', 'relative', 'tie', 'account', 'involvement', 'ties', 'affair', 'engagement', 'contacts', 'rapport', 'connection', 'dealing', 'terms', 'regards', 'concerned', 'comparison', 'linkage', 'motherhood', 'maternity', 'paternity', 'fatherhood', 'subjection', 'birth', 'romance', 'life', 'understanding', 'shared', 'future', 'complicated', 'marriage', 'ally', 'feelings', 'intereseted', 'personality', 'mutual', 'personal', 'incest', 'foster', 'absence', 'bilateral', 'sense', 'resolve', 'cousin', 'business relationship', 'love affair', 'personal relation', 'friendly relationship', 'blood kinship', 'marital bed', 'line of descent', 'sexual relationship', 'marital relationship', 'phylogenetic relationship', 'aunt', 'familial', 'fraternal', 'sister', 'nephew', 'grandniece', 'analogy', 'siblinghood', 'framily', 'brother', 'heteronymous', 'neighbourship', 'granddaughter', 'nieceship', 'niece', 'kiss cousin', 'social relation', 'stepbrother', 'intimacy', 'uncle', 'spousal', 'stepsister', 'familywise', 'hookup', 'nonmarriage', 'private life', 'stepfamily', 'interaction', 'lust', 'platonic love', 'affection', 'kindness', 'pleasure', 'compassion', 'sex', 'hate', 'heart', 'emotion', 'religion', 'sexual attraction', 'passion', 'lover', 'fight', 'lie'],
    'work': ['work', 'job', 'turn', 'ferment', 'exercise', 'play', 'sour', 'work out', 'labor', 'go', 'employment', 'put to work', 'process', 'bring', 'workplace', 'toil', 'coursework', 'forge', 'make', 'labour', 'housewifery', 'service', 'exchange', 'studio', 'answer', 'workpiece', 'spadework', 'ironwork', 'leatherwork', 'lacework', 'employ', 'metalwork', 'paperwork', 'nightwork', 'writing', 'welfare work', 'lacquerware', 'learning', 'masterpiece', 'silverwork', 'task', 'workload', 'crop', 'run', 'operate', 'function', 'wreak', 'work on', 'act', 'puzzle out', 'make for', 'piece of work', 'do work', 'project', 'deal', 'work ethic', 'deal', 'exploit', 'overwork', 'worker', 'housekeeping', 'business', 'task', 'employment', 'vocation', 'money', 'subcontract', 'profession', 'career', 'employer', 'place', 'duty', 'workplace', 'hire', 'internship', 'problem', 'chore', 'volunteer', 'position', 'laborer', 'handyman', 'occupation', 'application', 'appointment', 'computing'], 
    'school' : ['school', 'education', 'university', 'academy', 'college', 'teacher', 'classroom', 'grammar school', 'student', 'primary school', 'secondary school', 'educate', 'vocational school', 'seminary', 'schoolhouse', 'kindergarten', 'educational institution', 'conservatory', 'day school', 'shoal', 'public school', 'elementary school', 'private school', 'middle school', 'graduate school', 'curriculum', 'academic', 'gymnasium', 'schoolteacher', 'lyceum', 'deconstructivism', 'schoolroom', 'institution', 'survey', 'learn', 'read', 'research', 'report', 'analyze', 'compary', 'essay', 'major', 'memorizer', 'science', 'learning', 'examination', 'graduation', 'review', 'concentration', 'memorise', 'discipline', 'field of study', 'subject field', 'subject area', 'graduate', 'knowledge', 'researchers', 'analysis', 'schoolwork', 'preparation', 'homework', 'coursework', 'tutoring', 'typing', 'teaching', 'prep', 'lesson', 'tutorial', 'basics', 'housework', 'kids', 'math', 'errands', 'assignments', 'preschool', 'tasks', 'exams', 'paperwork', 'mathematics', 'english', 'history', 'literature', 'thesis', 'fail', 'delay', 'language', 'geography', 'course' ]
    }

# %%
df_journal = df_journal.dropna(subset = ['id'])
df_journal_lang = df_journal
df_journal_lang['description_split'] = df_journal_lang['description'].str.rsplit()
df_journal_lang['length'] = df_journal_lang.description_split.str.len() 
df_journal_lang = df_journal_lang[df_journal_lang['length'] > 20]  
display(df_journal_lang)
# Out:
#       id  type                       tag  \
# 1    3.0   did                 hoofdpijn
# 2    4.0   did                    school
# 3    5.0  wish            Tentamenstress
# 4    6.0  wish                      Werk
# 7    9.0   did            #lichaamsbeeld
# 9   11.0   did                      Werk
# 11  13.0  wish                        es
# 12  14.0   did             innerlijkkind
# 14  15.0  wish                       Sad
# 15  16.0  wish            Schaatsweekend
# 16  17.0  wish                 Vrijetijd
# 17  18.0  wish                    School
# 18  19.0   did                      Werk
# 19  20.0   did                 Hoofdpijn
# 22  23.0  wish                       Moe
# 25  26.0  wish                   Sporten
# 30  31.0   did                      Rust
# 31  32.0   did  Toegevenaanmijnbehoeften
# 32  33.0  wish                  studeren
# 34  35.0   did                    School
# 35  37.0   did                      Werk
# 36  38.0   did            Tentamenstress
# 39  41.0   did                      Werk
# 41  43.0  wish                 Hardlopen
# 49  51.0  wish          spanningenstress
# 50  52.0  wish               opmerkingen
# 51  55.0   did        slechtevriendinnen
# 52  56.0   did             zelfcompassie
# 53  57.0  wish             zelfcompassie
#
#                                           description  \
# 1   Vanmiddag had ik weer zo veel hofodpijn en toe...
# 2   Ik moest eigenlijk nog dingen doen voor school...
# 3   Vandaag had ik tentamen training en in plaats ...
# 4   Vandaag had ik een situatie op werk waar ik mi...
# 7   Ik had een leuke outfit aan en voelde me goed ...
# 9   Vandaag stuitte ik weer op een fout op werk. D...
# 11  Spanning na het afronden van de therapie, het ...
# 12  Ik merk dat ik vandaag heel erg stemmen in mij...
# 14  De foto's van mijn bachelor uitreiking waren t...
# 15  Ik had zelfcompassie willen gebruiken; afgelop...
# 16  Vandaag was er een vreemde situatie op straat....
# 17  Vandaag was gewoon niet mijn dag. Wilde zoveel...
# 18  Ik was enorm aan het twijfelen om een berichtj...
# 19  Ik heb nu 13 dagen achter elkaar hoofdpijn. Ik...
# 22  Vandaag weer bijna niks gedaan aan school en i...
# 25  Heb nu weer 3x gesport, daar mag ik dan blij m...
# 30  Ik heb vandaag heel rustig aan gedaan en gedaa...
# 31  Ik was vanmiddag ontzettend moe. In plaats van...
# 32  Stres voor het examen, ik neem het mezelf kwal...
# 34  Ik heb een toets gehaald met een 5.7. Is het h...
# 35  Ik had op werk opnieuw een situatie waar ik ee...
# 36  Een tentamen ging niet helemaal lekker en mees...
# 39  Op werk is er een mevrouw die heel ondankbaar ...
# 41  Vandaag een keer hardgelopen. Ging niet fantas...
# 49  m'n ouders zijn allebei best wel vaak gestress...
# 50  ik wou dat ik zelfcompassie had gebruikt, als ...
# 51  ik heb een paar jaar geleden gebroken met vrie...
# 52  Ik ben bang dat ik dingen niet goed genoeg doe...
# 53  Ik merk dat ik door dit dagboek me er meer van...
#
#                      timestamp  \
# 1   2021-02-17 19:47:36.805740
# 2   2021-02-21 18:22:06.053739
# 3   2021-02-22 16:09:59.314627
# 4   2021-02-22 16:40:59.017889
# 7   2021-02-24 16:24:48.218147
# 9   2021-02-24 20:07:38.360436
# 11  2021-02-25 21:36:14.009571
# 12  2021-02-26 21:35:15.147216
# 14  2021-02-27 19:53:20.084984
# 15  2021-02-28 11:24:11.558382
# 16  2021-02-28 18:08:07.324579
# 17  2021-03-01 22:24:25.792938
# 18  2021-03-02 18:15:45.984676
# 19  2021-03-02 18:44:04.099462
# 22  2021-03-02 21:23:10.392090
# 25  2021-03-09 18:48:32.312366
# 30  2021-03-14 22:50:18.986355
# 31  2021-03-15 20:53:07.901158
# 32  2021-03-15 21:08:00.435791
# 34  2021-03-22 21:06:08.096286
# 35  2021-03-25 17:35:58.437440
# 36  2021-03-25 21:08:43.439381
# 39  2021-03-30 19:23:27.920015
# 41  2021-03-31 18:18:33.511377
# 49  2021-04-18 18:50:39.672850
# 50  2021-04-19 19:19:29.484686
# 51  2021-04-25 16:50:56.020915
# 52  2021-04-25 22:27:39.923943
# 53  2021-04-27 20:50:42.468182
#
#                                        sc_description  rating  id_user  \
# 1   In plaats van kritisch te zijn, was ik aardig ...     4.0      6.0
# 2   In plaats van kritisch te zijn, was ik aardig ...     4.0      6.0
# 3   Ik accepteerde de negatieve emoties, en ging t...     NaN     10.0
# 4   Ik vond het stom dat ik door mijn eigen onzeke...     NaN     11.0
# 7   Ik accepteerde de negatieve emoties, en ging t...     3.0     13.0
# 9   In plaats van kritisch te zijn, was ik aardig ...     2.0     11.0
# 11  Je hebt even de vrijheid en het is logisch dat...     NaN     13.0
# 12  Lieve X, je doet het zo ontzettend goed. En el...     3.0     12.0
# 14  Dat ik gewoon blij kan zijn met mijzelf. Dat i...     NaN     24.0
# 15  Gedeelde menselijkheid: wat je op de foto's zi...     NaN     20.0
# 16  Ik moet inzien dat ik niet iedereen kan helpen...     NaN     11.0
# 17  Ik onthoud dat iedereen het soms moeilijk heef...     NaN     10.0
# 18  In plaats van kritisch te zijn, was ik aardig ...     4.0     11.0
# 19  In plaats van kritisch te zijn, was ik aardig ...     2.0     20.0
# 22  Ik onthoud dat iedereen het soms moeilijk heef...     NaN     10.0
# 25  In plaats van kritisch te zijn, aardig te zijn...     NaN     20.0
# 30  Ik accepteerde de negatieve emoties, en ging t...     4.0     26.0
# 31  In plaats van kritisch te zijn, was ik aardig ...     4.0     26.0
# 32  Ik onthoud dat iedereen het soms moeilijk heef...     NaN     13.0
# 34  In plaats van kritisch te zijn, was ik aardig ...     5.0     10.0
# 35                              Heb het gerelativeerd     5.0     11.0
# 36  Ik accepteerde de negatieve emoties, en ging t...     4.0     10.0
# 39                                        Relativeren     4.0     11.0
# 41  In plaats van kritisch te zijn, was ik aardig ...     NaN     20.0
# 49  In plaats van kritisch te zijn, was ik aardig ...     NaN     30.0
# 50  In plaats van kritisch te zijn, was ik aardig ...     NaN     30.0
# 51  In plaats van kritisch te zijn, was ik aardig ...     2.0     30.0
# 52  In plaats van kritisch te zijn, was ik aardig ...     5.0     33.0
# 53  Ik onthoud dat iedereen het soms moeilijk heef...     NaN     33.0
#
#          gold_label                                  description_split  length
# 1            school  [Vanmiddag, had, ik, weer, zo, veel, hofodpijn...      89
# 2            school  [Ik, moest, eigenlijk, nog, dingen, doen, voor...      27
# 3            school  [Vandaag, had, ik, tentamen, training, en, in,...      53
# 4              work  [Vandaag, had, ik, een, situatie, op, werk, wa...     206
# 7   body insecurity  [Ik, had, een, leuke, outfit, aan, en, voelde,...      73
# 9              work  [Vandaag, stuitte, ik, weer, op, een, fout, op...      86
# 11         no topic  [Spanning, na, het, afronden, van, de, therapi...      42
# 12    relationships  [Ik, merk, dat, ik, vandaag, heel, erg, stemme...      97
# 14         no topic  [De, foto's, van, mijn, bachelor, uitreiking, ...      60
# 15   social anxiety  [Ik, had, zelfcompassie, willen, gebruiken;, a...      51
# 16   social anxiety  [Vandaag, was, er, een, vreemde, situatie, op,...     140
# 17           school  [Vandaag, was, gewoon, niet, mijn, dag., Wilde...      33
# 18             work  [Ik, was, enorm, aan, het, twijfelen, om, een,...     125
# 19           school  [Ik, heb, nu, 13, dagen, achter, elkaar, hoofd...      43
# 22           school  [Vandaag, weer, bijna, niks, gedaan, aan, scho...      30
# 25         no topic  [Heb, nu, weer, 3x, gesport,, daar, mag, ik, d...      36
# 30         no topic  [Ik, heb, vandaag, heel, rustig, aan, gedaan, ...      63
# 31         no topic  [Ik, was, vanmiddag, ontzettend, moe., In, pla...      45
# 32           school  [Stres, voor, het, examen,, ik, neem, het, mez...      21
# 34           school  [Ik, heb, een, toets, gehaald, met, een, 5.7.,...      23
# 35             work  [Ik, had, op, werk, opnieuw, een, situatie, wa...      59
# 36           school  [Een, tentamen, ging, niet, helemaal, lekker, ...      29
# 39             work  [Op, werk, is, er, een, mevrouw, die, heel, on...     103
# 41  body insecurity  [Vandaag, een, keer, hardgelopen., Ging, niet,...      66
# 49    relationships  [m'n, ouders, zijn, allebei, best, wel, vaak, ...      38
# 50    relationships  [ik, wou, dat, ik, zelfcompassie, had, gebruik...      39
# 51    relationships  [ik, heb, een, paar, jaar, geleden, gebroken, ...      22
# 52         no topic  [Ik, ben, bang, dat, ik, dingen, niet, goed, g...      23
# 53         no topic  [Ik, merk, dat, ik, door, dit, dagboek, me, er...     102

# %%
def tokenize(text):
    lda_tokens = []
    tokens = parser(text)
    for token in tokens:
        if token.orth_.isspace():
            continue
        elif token.like_url:
            lda_tokens.append('URL')
        elif token.orth_.startswith('@'):
            lda_tokens.append('SCREEN_NAME')
        else:
            lda_tokens.append(token.lower_)
    return lda_tokens

def lemma1(word):
    return WordNetLemmatizer().lemmatize(word)

def lemma2(word):
    return WordNetLemmatizer().lemmatize(word,'v')

def prepare_text(text):
    tokens = tokenize(text)
    tokens = [token for token in tokens if len(token) > 2] #check what works best 
    #tokens = [porter.stem(token) for token in tokens] #stemming
    tokens = [token for token in tokens if token not in en_stop]
    tokens = [lemma1(token) for token in tokens] #lemmatization 
    tokens = [lemma2(token) for token in tokens] #lemmatization verbs
    return tokens

def prepare_topics(topics):
    for topic in topics: 
        prepared_words = [] 
        for string in topics[topic]:
            string = prepare_text(string)
            prepared_words.append(string)
            res = []
            [res.append(x) for x in prepared_words if x not in res] 
            res = [' '.join(map(str, i)) for i in res]
        topics[topic] = res
    return topics 

def sentiment_analyzer(sentence):
    score = analyser.polarity_scores(sentence)
    negative_score = score['neg']
    positive_score = score['pos']
    neutral_score = score['neu']
    difference = abs(negative_score - positive_score)
    if neutral_score > 0.8:
        return 'neutral'
    elif difference <0.1:
        return 'neutral'
    elif negative_score > positive_score:
        return 'negative'
    else:
        return 'positive'

def dutch_translator(text):
    result = translator.translate(text, dest='en',  src='nl')
    return result.text

def eng_translator(text):
    result = translator.translate(text, dest='nl',  src='en')
    return result.text

# %%
df_journal_lang['description_eng'] = df_journal_lang.apply(lambda row: dutch_translator(row.description), axis = 1)
df_journal_lang['tag'] = df_journal_lang.apply(lambda row: dutch_translator(row.tag), axis = 1)
df_journal_lang['prepared_description'] = df_journal_lang.apply(lambda row: prepare_text(row.description_eng), axis = 1)
df_journal_lang = df_journal_lang.drop(['timestamp', 'rating', 'sc_description', 'length', 'description_split'], axis = 'columns')
display(df_journal_lang)
# Out:
# /Users/ninagroot/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/ninagroot/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/ninagroot/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#       id  type                  tag  \
# 1    3.0   did             headache
# 2    4.0   did               school
# 3    5.0  wish          Exam stress
# 4    6.0  wish                 Work
# 7    9.0   did          #body image
# 9   11.0   did                 Work
# 11  13.0  wish                   es
# 12  14.0   did          inner child
# 14  15.0  wish                  Sad
# 15  16.0  wish      Skating weekend
# 16  17.0  wish              Leisure
# 17  18.0  wish               School
# 18  19.0   did                 Work
# 19  20.0   did             Headache
# 22  23.0  wish                tired
# 25  26.0  wish               sports
# 30  31.0   did                Peace
# 31  32.0   did  Give in to my needs
# 32  33.0  wish             to study
# 34  35.0   did               School
# 35  37.0   did                 Work
# 36  38.0   did          Exam stress
# 39  41.0   did                 Work
# 41  43.0  wish              Running
# 49  51.0  wish       tension stress
# 50  52.0  wish              remarks
# 51  55.0   did          bad friends
# 52  56.0   did      self-compassion
# 53  57.0  wish      self-compassion
#
#                                           description  id_user  \
# 1   Vanmiddag had ik weer zo veel hofodpijn en toe...      6.0
# 2   Ik moest eigenlijk nog dingen doen voor school...      6.0
# 3   Vandaag had ik tentamen training en in plaats ...     10.0
# 4   Vandaag had ik een situatie op werk waar ik mi...     11.0
# 7   Ik had een leuke outfit aan en voelde me goed ...     13.0
# 9   Vandaag stuitte ik weer op een fout op werk. D...     11.0
# 11  Spanning na het afronden van de therapie, het ...     13.0
# 12  Ik merk dat ik vandaag heel erg stemmen in mij...     12.0
# 14  De foto's van mijn bachelor uitreiking waren t...     24.0
# 15  Ik had zelfcompassie willen gebruiken; afgelop...     20.0
# 16  Vandaag was er een vreemde situatie op straat....     11.0
# 17  Vandaag was gewoon niet mijn dag. Wilde zoveel...     10.0
# 18  Ik was enorm aan het twijfelen om een berichtj...     11.0
# 19  Ik heb nu 13 dagen achter elkaar hoofdpijn. Ik...     20.0
# 22  Vandaag weer bijna niks gedaan aan school en i...     10.0
# 25  Heb nu weer 3x gesport, daar mag ik dan blij m...     20.0
# 30  Ik heb vandaag heel rustig aan gedaan en gedaa...     26.0
# 31  Ik was vanmiddag ontzettend moe. In plaats van...     26.0
# 32  Stres voor het examen, ik neem het mezelf kwal...     13.0
# 34  Ik heb een toets gehaald met een 5.7. Is het h...     10.0
# 35  Ik had op werk opnieuw een situatie waar ik ee...     11.0
# 36  Een tentamen ging niet helemaal lekker en mees...     10.0
# 39  Op werk is er een mevrouw die heel ondankbaar ...     11.0
# 41  Vandaag een keer hardgelopen. Ging niet fantas...     20.0
# 49  m'n ouders zijn allebei best wel vaak gestress...     30.0
# 50  ik wou dat ik zelfcompassie had gebruikt, als ...     30.0
# 51  ik heb een paar jaar geleden gebroken met vrie...     30.0
# 52  Ik ben bang dat ik dingen niet goed genoeg doe...     33.0
# 53  Ik merk dat ik door dit dagboek me er meer van...     33.0
#
#          gold_label                                    description_eng  \
# 1            school  This afternoon I had so much hofod pain again ...
# 2            school  I actually had to do things for school such as...
# 3            school  Today I had exam training and instead of telli...
# 4              work  Today I had a situation at work where I heard ...
# 7   body insecurity  I was wearing a nice outfit and felt good when...
# 9              work  Today I ran into another mistake at work. Not ...
# 11         no topic  Tension after finishing the therapy, I felt li...
# 12    relationships  I notice that today I heard very many voices i...
# 14         no topic  I thought the photos of my bachelor's ceremony...
# 15   social anxiety  I would have liked to use self-compassion; las...
# 16   social anxiety  Today there was a strange situation on the str...
# 17           school  Today just wasn't my day. Wanted to do so much...
# 18             work  I was very hesitant to message a particular bu...
# 19           school  I now have a headache for 13 days in a row. I ...
# 22           school  Today almost nothing has been done at school a...
# 25         no topic  I have now exercised 3x again, I may be happy ...
# 30         no topic  Today I took it easy and did what felt right. ...
# 31         no topic  I was very tired this afternoon. Instead of st...
# 32           school  Stress for the exam, I blame myself for not tr...
# 34           school  I passed a test with a 5.7. Is it high no, but...
# 35             work  I had another situation at work where I had ma...
# 36           school  An exam didn't go well and I usually get so an...
# 39             work  At work there is a lady who is very ungrateful...
# 41  body insecurity  Running once today. Didn't go great. I was not...
# 49    relationships  my parents are both stressed and agitated quit...
# 50    relationships  I wish I had used self-compassion when I got s...
# 51    relationships  I broke up with friends a few years ago who tu...
# 52         no topic  I fear that I am not doing things well enough,...
# 53         no topic  I find that this journal makes me more aware t...
#
#                                  prepared_description
# 1   [afternoon, much, hofod, pain, think, appoint,...
# 2   [actually, thing, school, read, chapter, also,...
# 3   [today, exam, train, instead, tell, go, work, ...
# 4   [today, situation, work, hear, name, mention, ...
# 7   [wear, nice, outfit, felt, good, put, slander,...
# 9   [today, run, another, mistake, work, big, time...
# 11  [tension, finish, therapy, felt, like, free, c...
# 12  [notice, today, hear, many, voice, head, han, ...
# 14  [think, photo, bachelor, ceremony, turn, beaut...
# 15  [would, like, use, self, compassion, last, wee...
# 16  [today, strange, situation, street, go, hike, ...
# 17  [today, n't, day, want, much, school, n't, wor...
# 18  [hesitant, message, particular, business, info...
# 19  [headache, day, row, proud, fact, morning, wor...
# 22  [today, almost, nothing, do, school, feel, hap...
# 25  [exercise, may, happy, proud, instead, focus, ...
# 30  [today, take, easy, felt, right, sleep, tire, ...
# 31  [tire, afternoon, instead, stick, schedule, co...
# 32  [stress, exam, blame, try, enough, start, earl...
# 34              [pass, test, 5.7, high, quite, proud]
# 35  [another, situation, work, make, mistake, howe...
# 36  [exam, n't, well, usually, get, angry, think, ...
# 39  [work, lady, ungrateful, find, incompetent, yo...
# 41  [run, today, n't, great, happy, condition, mix...
# 49  [parent, stress, agitate, quite, often, child,...
# 50  [wish, use, self, compassion, get, stupid, med...
# 51  [break, friend, year, ago, turn, friend, good,...
# 52  [fear, thing, well, enough, practice, see, eve...
# 53  [find, journal, make, aware, always, self, com...

# %%
df_journal_lang.to_excel('prepared_journal_model2_lang.xlsx')

# %%
prepared_topics = prepare_topics(topics)
df_journal['description_eng'] = df_journal.apply(lambda row: dutch_translator(row.description), axis = 1)
df_journal['prepared_description'] = df_journal.apply(lambda row: prepare_text(row.description_eng), axis = 1)
df_journal = df_journal.drop(['timestamp', 'rating', 'sc_description', 'length', 'description_split'], axis = 'columns')
display(df_journal)
# Out:
#       id  type                       tag  \
# 0    2.0  wish                   Rooster
# 1    3.0   did                 hoofdpijn
# 2    4.0   did                    school
# 3    5.0  wish            Tentamenstress
# 4    6.0  wish                      Werk
# 5    7.0   did                    metime
# 6    8.0  wish                    school
# 7    9.0   did            #lichaamsbeeld
# 8   10.0  wish                    school
# 9   11.0   did                      Werk
# 10  12.0  wish             innerlijkkind
# 11  13.0  wish                        es
# 12  14.0   did             innerlijkkind
# 14  15.0  wish                       Sad
# 15  16.0  wish            Schaatsweekend
# 16  17.0  wish                 Vrijetijd
# 17  18.0  wish                    School
# 18  19.0   did                      Werk
# 19  20.0   did                 Hoofdpijn
# 20  21.0  wish                    school
# 21  22.0  wish             lichaamsbeeld
# 22  23.0  wish                       Moe
# 23  24.0   did                    studie
# 24  25.0   did                  studeren
# 25  26.0  wish                   Sporten
# 26  27.0   did                      Rust
# 27  28.0   did                      Rust
# 28  29.0   did                        es
# 29  30.0   did                        NS
# 30  31.0   did                      Rust
# 31  32.0   did  Toegevenaanmijnbehoeften
# 32  33.0  wish                  studeren
# 33  34.0   did                  vrienden
# 34  35.0   did                    School
# 35  37.0   did                      Werk
# 36  38.0   did            Tentamenstress
# 37  39.0   did                      hulp
# 38  40.0   did                    Grezen
# 39  41.0   did                      Werk
# 40  42.0  wish             lichaamsbeeld
# 41  43.0  wish                 Hardlopen
# 42  44.0  wish                     Brood
# 43  45.0  wish                      Eten
# 44  46.0  wish             werkmotivatie
# 45  47.0   did                        es
# 46  48.0  wish             werkmotivatie
# 47  49.0  wish                  Wandelen
# 48  50.0   did                   fietsen
# 49  51.0  wish          spanningenstress
# 50  52.0  wish               opmerkingen
# 51  55.0   did        slechtevriendinnen
# 52  56.0   did             zelfcompassie
# 53  57.0  wish             zelfcompassie
# 54  58.0   did             zelfcompassie
#
#                                           description  id_user  \
# 0   Indelen van diensten. Gekozen om zelf te gaan ...      5.0
# 1   Vanmiddag had ik weer zo veel hofodpijn en toe...      6.0
# 2   Ik moest eigenlijk nog dingen doen voor school...      6.0
# 3   Vandaag had ik tentamen training en in plaats ...     10.0
# 4   Vandaag had ik een situatie op werk waar ik mi...     11.0
# 5   Vandaag veel gedaan wat ik zelf wilde. Dus ech...     10.0
# 6   Dat ik wilde chillen na school maar het lukte ...      6.0
# 7   Ik had een leuke outfit aan en voelde me goed ...     13.0
# 8   Ik moet eigenlijk nog veel doen voor school, m...      6.0
# 9   Vandaag stuitte ik weer op een fout op werk. D...     11.0
# 10  Toen ik vroeger klein was. Ik had gewoon een k...     12.0
# 11  Spanning na het afronden van de therapie, het ...     13.0
# 12  Ik merk dat ik vandaag heel erg stemmen in mij...     12.0
# 14  De foto's van mijn bachelor uitreiking waren t...     24.0
# 15  Ik had zelfcompassie willen gebruiken; afgelop...     20.0
# 16  Vandaag was er een vreemde situatie op straat....     11.0
# 17  Vandaag was gewoon niet mijn dag. Wilde zoveel...     10.0
# 18  Ik was enorm aan het twijfelen om een berichtj...     11.0
# 19  Ik heb nu 13 dagen achter elkaar hoofdpijn. Ik...     20.0
# 20                    Soms is het gewoon even te veel      6.0
# 21                              stress voor skillslab     13.0
# 22  Vandaag weer bijna niks gedaan aan school en i...     10.0
# 23  Veel gedaan vandaag maar had nog meer willen doen     13.0
# 24  Druk maar toch even naar buiten geweest en pau...     13.0
# 25  Heb nu weer 3x gesport, daar mag ik dan blij m...     20.0
# 26  Ik heb dit weekend het rustiger aan gedaan om ...     10.0
# 27            Vandaag even niks gedaan.. was heerlijk     10.0
# 28         Om hulp gevraagd en kwetsbaarheid getoond.     13.0
# 29                           Gisteren, lange OV reis.     20.0
# 30  Ik heb vandaag heel rustig aan gedaan en gedaa...     26.0
# 31  Ik was vanmiddag ontzettend moe. In plaats van...     26.0
# 32  Stres voor het examen, ik neem het mezelf kwal...     13.0
# 33  Eerlijk geweest tegen een vriendin en geaccept...     13.0
# 34  Ik heb een toets gehaald met een 5.7. Is het h...     10.0
# 35  Ik had op werk opnieuw een situatie waar ik ee...     11.0
# 36  Een tentamen ging niet helemaal lekker en mees...     10.0
# 37  Eerlijk geweest over mijn gevoel en om hulp ge...     13.0
# 38   Ik heb vandaag duidelijk mijn grenzen aangegeven     10.0
# 39  Op werk is er een mevrouw die heel ondankbaar ...     11.0
# 40  Mislukte kapperspoging, ik vond mezelf niet mo...     13.0
# 41  Vandaag een keer hardgelopen. Ging niet fantas...     20.0
# 42  Ik liet brood aanbranden, maar ik werd boos op...     28.0
# 43  Ik heb vandaag weinig gedaan en veel slecht ge...     28.0
# 44      Ik had weinig motivatie om vandaag te werken.     28.0
# 45            Ik gaf toe aan mijn rationele gedachten     13.0
# 46  ik kwam in de ochtend moeilijk op gang op het ...     28.0
# 47  Ik had geen zin om te wandelen maar voelde me ...     28.0
# 48  Ik wilde niet meegaan fietsen, voelde mij eers...     28.0
# 49  m'n ouders zijn allebei best wel vaak gestress...     30.0
# 50  ik wou dat ik zelfcompassie had gebruikt, als ...     30.0
# 51  ik heb een paar jaar geleden gebroken met vrie...     30.0
# 52  Ik ben bang dat ik dingen niet goed genoeg doe...     33.0
# 53  Ik merk dat ik door dit dagboek me er meer van...     33.0
# 54                  Ik heb nu geen zin om dit te doen     33.0
#
#          gold_label                                    description_eng  \
# 0              work  Classification of services. Chosen to go mysel...
# 1            school  This afternoon I had so much hofod pain again ...
# 2            school  I actually had to do things for school such as...
# 3            school  Today I had exam training and instead of telli...
# 4              work  Today I had a situation at work where I heard ...
# 5          no topic  Today much done what I wanted myself. So reall...
# 6            school  That I wanted to chill out after school but I ...
# 7   body insecurity  I was wearing a nice outfit and felt good when...
# 8            school  I still have a lot to do for school, but it is...
# 9              work  Today I ran into another mistake at work. Not ...
# 10         no topic  When I used to be little. I just needed a hug,...
# 11         no topic  Tension after finishing the therapy, I felt li...
# 12     relationship  I notice that today I heard very many voices i...
# 14         no topic  I thought the photos of my bachelor's ceremony...
# 15   social anxiety  I would have liked to use self-compassion; las...
# 16   social anxiety  Today there was a strange situation on the str...
# 17           school  Today just wasn't my day. Wanted to do so much...
# 18             work  I was very hesitant to message a particular bu...
# 19           school  I now have a headache for 13 days in a row. I ...
# 20         no topic                      Sometimes it is just too much
# 21         no topic                              stress for skills lab
# 22           school  Today almost nothing has been done at school a...
# 23         no topic   Done a lot today but would have liked to do more
# 24         no topic        Busy but still went outside and took breaks
# 25         no topic  I have now exercised 3x again, I may be happy ...
# 26         no topic  I took it slower this weekend to give myself a...
# 27         no topic              Didn't do anything today .. was great
# 28         no topic          Asked for help and exposed vulnerability.
# 29         no topic          Yesterday, long public transport journey.
# 30         no topic  Today I took it easy and did what felt right. ...
# 31         no topic  I was very tired this afternoon. Instead of st...
# 32           school  Stress for the exam, I blame myself for not tr...
# 33       friendship  Been honest with a friend and accepted that I ...
# 34           school  I passed a test with a 5.7. Is it high no, but...
# 35             work  I had another situation at work where I had ma...
# 36           school  An exam didn't go well and I usually get so an...
# 37         no topic        Been honest about my gut and asked for help
# 38         no topic                 I have clearly set my limits today
# 39             werk  At work there is a lady who is very ungrateful...
# 40  body insecurity  Failed hairdresser attempt, I didn't think I w...
# 41  body insecurity  Running once today. Didn't go great. I was not...
# 42         no topic  I burned bread, but I got mad at myself. I cou...
# 43         no topic          Today I did little and I ate a lot badly.
# 44             work             I had little motivation to work today.
# 45         no topic                  I gave in to my rational thoughts
# 46             work  I had a hard time getting started at work in t...
# 47         no topic  I didn't feel like walking but felt obliged an...
# 48   social anxiety  I didn't want to go cycling, I felt guilty at ...
# 49     relationship  my parents are both stressed and agitated quit...
# 50     relationship  I wish I had used self-compassion when I got s...
# 51       friendship  I broke up with friends a few years ago who tu...
# 52         no topic  I fear that I am not doing things well enough,...
# 53         no topic  I find that this journal makes me more aware t...
# 54         no topic             I don't feel like doing this right now
#
#                                  prepared_description
# 0   [classification, service, choose, know, others...
# 1   [afternoon, much, hofod, pain, think, appoint,...
# 2   [actually, thing, school, read, chapter, also,...
# 3   [today, exam, train, instead, tell, go, work, ...
# 4   [today, situation, work, hear, name, mention, ...
# 5   [today, much, do, want, really, take, time, want]
# 6                   [want, chill, school, could, n't]
# 7   [wear, nice, outfit, felt, good, put, slander,...
# 8   [still, lot, school, already, quite, late, tom...
# 9   [today, run, another, mistake, work, big, time...
# 10                  [use, little, need, hug, someone]
# 11  [tension, finish, therapy, felt, like, free, c...
# 12  [notice, today, hear, many, voice, head, han, ...
# 14  [think, photo, bachelor, ceremony, turn, beaut...
# 15  [would, like, use, self, compassion, last, wee...
# 16  [today, strange, situation, street, go, hike, ...
# 17  [today, n't, day, want, much, school, n't, wor...
# 18  [hesitant, message, particular, business, info...
# 19  [headache, day, row, proud, fact, morning, wor...
# 20                                  [sometimes, much]
# 21                               [stress, skill, lab]
# 22  [today, almost, nothing, do, school, feel, hap...
# 23                      [do, lot, today, would, like]
# 24            [busy, still, go, outside, take, break]
# 25  [exercise, may, happy, proud, instead, focus, ...
# 26                [take, slower, weekend, give, rest]
# 27                      [n't, anything, today, great]
# 28                 [ask, help, expose, vulnerability]
# 29      [yesterday, long, public, transport, journey]
# 30  [today, take, easy, felt, right, sleep, tire, ...
# 31  [tire, afternoon, instead, stick, schedule, co...
# 32  [stress, exam, blame, try, enough, start, earl...
# 33        [honest, friend, accept, could, vulnerable]
# 34              [pass, test, 5.7, high, quite, proud]
# 35  [another, situation, work, make, mistake, howe...
# 36  [exam, n't, well, usually, get, angry, think, ...
# 37                           [honest, gut, ask, help]
# 38                       [clearly, set, limit, today]
# 39  [work, lady, ungrateful, find, incompetent, yo...
# 40  [fail, hairdresser, attempt, n't, think, beaut...
# 41  [run, today, n't, great, happy, condition, mix...
# 42  [burn, bread, get, mad, could, react, lenientl...
# 43                   [today, little, eat, lot, badly]
# 44                  [little, motivation, work, today]
# 45                            [give, rational, think]
# 46     [hard, time, get, start, work, morning, blame]
# 47  [n't, feel, like, walk, felt, oblige, go, anyway]
# 48  [n't, want, cycle, felt, guilty, first, might,...
# 49  [parent, stress, agitate, quite, often, child,...
# 50  [wish, use, self, compassion, get, stupid, med...
# 51  [break, friend, year, ago, turn, friend, good,...
# 52  [fear, thing, well, enough, practice, see, eve...
# 53  [find, journal, make, aware, always, self, com...
# 54                           [n't, feel, like, right]

# %%
df_journal.to_excel('prepared_journal_model2.xlsx')
